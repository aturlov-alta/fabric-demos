# %%
# %%sql
# REFRESH MATERIALIZED LAKE VIEW silver.mlv_addresses;
# REFRESH MATERIALIZED LAKE VIEW silver.mlv_customers;
# REFRESH MATERIALIZED LAKE VIEW silver.mlv_products;
# REFRESH MATERIALIZED LAKE VIEW silver.mlv_salesheaders;
# REFRESH MATERIALIZED LAKE VIEW silver.mlv_saleslines;
